# %% [markdown]
# ## Notebook Description

# %% [markdown]
# ## Required Libraries

# %%
# Data Manipulation
import numpy as np
import pandas as pd

import json

# Visualizations
import matplotlib.pyplot as plt

# Operating System
import os

# Model Development

from sklearn.model_selection import StratifiedKFold

# Convenience
from tqdm import tqdm

# Bias Detection
from medicalbiasdetection import utils


# Notebook Operating Conditions
pd.set_option('display.max_rows', 250)
pd.set_option('display.max_columns', 250)
import warnings
warnings.filterwarnings("ignore")

config = utils.read_yaml()

# Global Variables
RUN = 1
RANDOM_STATE = 0


LOG_DIR = config['LOG']['dir'].format(RUN=RUN)
LOG_PATH = config['LOG']['path'].format(RUN=RUN)
os.environ['LOG_PATH'] = LOG_PATH
os.environ['RUN'] = str(RUN)

from medicalbiasdetection import model as md
from medicalbiasdetection import cohort
from medicalbiasdetection import process
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Load Reference Data

# %%
# identify the medical facility for the dataset
med_fac = 'grady' # 'grady' # 'emory'
X = cohort.load_reference_data(med_fac,config, verbose=True)
# Out:
# Number of encounters (csn): 119733
# Years: [2016 2017 2018 2019 2020]
# Start year: 2016
# End year: 2020
# Number of unique patient visits: 119733
# Number of unique patients: 73484
# Number of sepsis=0 patients: 101269 (84.58%)
# Number of sepsis=1 patients: 18464 (15.42%)

# %% [markdown]
# ## Update Reference Data

# %%
X = cohort.update_cohort(X, verbose=True)
cohort.print_cohort_report(X,'csn','pat_id','sepsis')
# Out:
# Total CSNs included: 13289
# Removed CSNs:
# step           reason
# preprocessing  non-ICU patient                     101935
#                less than 24 hours of icu data        2616
#                corrupted file - did not process      1890
#                gender unknown                           3
# dtype: int64
# Number of encounters (csn): 13289
# Years: [2016 2017 2018 2019 2020]
# Start year: 2016
# End year: 2020
# Number of unique patient visits: 13289
# Number of unique patients: 12387
# Number of sepsis=1 patients: 4772 (35.91%)
# Number of sepsis=0 patients: 8517 (64.09%)

# %% [markdown]
# ## Load Hourly Data

# %%
df = cohort.load_hourly_data(config)
# Out:
# 100%|██████████| 5/5 [00:33<00:00,  6.72s/it]

# %% [markdown]
# ## Right-Censor Data

# %%
run_cell = True
if run_cell:
    sepsis_col = "sepsis_lag_6"

    sep_counts = df[sepsis_col].value_counts()
    n = df.shape[0]
    sep_counts_norm = df[sepsis_col].value_counts(normalize=True)
    print(f"Patient Hours before censoring: {df.shape[0]}")
    print(f"Non-sepsis hours = {sep_counts[0]} ({np.round(sep_counts_norm[0],2)*100}%)")
    print(f"Sepsis hours = {sep_counts[1]} ({np.round(sep_counts_norm[1],2)*100}%)")
    print("#"*50)

    df = cohort.right_censor(df,sepsis_col)

    sep_counts = df[sepsis_col].value_counts()
    sep_counts_norm = df[sepsis_col].value_counts(normalize=True)
    print(f"Patient Hours after censoring: {df.shape[0]}")
    print(f"Non-sepsis hours = {sep_counts[0]} ({np.round(sep_counts_norm[0],3)*100}%)")
    print(f"Sepsis hours = {sep_counts[1]} ({np.round(sep_counts_norm[1],3)*100}%)")

    print("#"*50)
    print(f"Removed {n - df.shape[0]} hours. {np.round(1-(df.shape[0]/n),2)*100}% Reduction")
# Out:
# Patient Hours before censoring: 1824827
# Non-sepsis hours = 1223081 (67.0%)
# Sepsis hours = 601746 (33.0%)
# ##################################################
# Patient Hours after censoring: 1227556
# Non-sepsis hours = 1223081 (99.6%)
# Sepsis hours = 4475 (0.4%)
# ##################################################
# Removed 597271 hours. 33.0% Reduction

# %% [markdown]
# ## Train, Test, Validation Sets
# - This is a two part train/test/validation split
# - The first split will be temporally based with patients admitted before 2018 comprising the training and validation sets
#   and patients after 2018 making up the test set
# - The second split for the training and validation data will be based on each patients information.
# - The first 24 hours of patient data will be used in the training set
# - Remaining hours following the first 24 will be used for the test set with a maximum number of hours available being 168 (7 days)

# %% [markdown]
# ## Temporal Splits

# %%
print("Temporal Split Report")
print("#"*50)
print("Training  & Validation")
cohort.print_cohort_report(X[X['year']<=2018],'csn','pat_id','sepsis')
print("#"*50)
print("Testing")
cohort.print_cohort_report(X[X['year']>2018],'csn','pat_id','sepsis')
# Out:
# Temporal Split Report
# ##################################################
# Training  & Validation
# Number of encounters (csn): 8128
# Years: [2016 2017 2018]
# Start year: 2016
# End year: 2018
# Number of unique patient visits: 8128
# Number of unique patients: 7724
# Number of sepsis=1 patients: 2953 (36.33%)
# Number of sepsis=0 patients: 5175 (63.67%)
# ##################################################
# Testing
# Number of encounters (csn): 5161
# Years: [2019 2020]
# Start year: 2019
# End year: 2020
# Number of unique patient visits: 5161
# Number of unique patients: 4883
# Number of sepsis=1 patients: 1819 (35.25%)
# Number of sepsis=0 patients: 3342 (64.75%)

# %%
run_cell = True
if run_cell:
    
    # Perform temporal splits
    X_train = X[X['year']<=2018]
    X_test = X[X['year']>2018]
    y_train = X_train['sepsis']
    y_test = X_test['sepsis']
    
    
    # get patient csns for training data
    csns_train = X_train.csn.unique().tolist()
    print(f"Number of patients in training set: {len(csns_train)}")
    cohort.print_cohort_report(X_train,'csn','pat_id','sepsis')

    # get patient csns for test data
    csns_test = X_test.csn.unique().tolist()
    print(f"Number of patients in test set: {len(csns_test)}")
    cohort.print_cohort_report(X_test,'csn','pat_id','sepsis')
    
    # Initialize Stratified K-Folds
    stkf = StratifiedKFold(n_splits=5)
    
    # Initialize arrays to collect training and validation sets
    train_sets = []
    val_sets = []
    ks = []

    # Perform StratifiedKFold on the combined dataset and store results
    for k, (train_idx, val_idx) in enumerate(stkf.split(X_train, y_train)):
        train_sets.append(X_train.iloc[train_idx])
        val_sets.append(X_train.iloc[val_idx])
        ks.append(k)


    # set parameters for time series split
    train_hours = 24 # 1 day
    max_hours = 168 # 7 days
    y = 'sepsis_lag_6'
    
    # set the save path
    path = config['DIR']['train_test_split'].format(RUN=RUN)
    
    # for each k-fold 
    for k in tqdm(ks):
        # get train csns
        train_csn_k = train_sets[k]['csn'].unique().tolist()

        # create temp training data df
        train_df_k = df[df['csn'].isin(train_csn_k)]

        # initialize arrays to store training and validation data
        X_train_list, y_train_list, X_val_list, y_val_list = [], [], [], []

       
        # for each patient in the training data
        for csn in train_csn_k:    
            # create temp df
            pat_df = train_df_k[train_df_k['csn']==csn]
            
            # perform time series split to create training and validation sets
            X_train_k, y_train_k, X_val_k, y_val_k = md.timeseries_train_test_split(pat_df, y, train_hours, max_hours)
            
            # append training and validation data
            X_train_list.append(X_train_k)
            y_train_list.append(y_train_k)
            X_val_list.append(X_val_k)
            y_val_list.append(y_val_k)

        # Concatenate results
        X_train_df = pd.concat(X_train_list, axis=0)
        y_train_df = pd.concat(y_train_list, axis=0)
        X_val_df = pd.concat(X_val_list, axis=0)
        y_val_df = pd.concat(y_val_list, axis=0)

        # save datasets
        filepath = f"{path}X_train_{k}.csv"
        X_train_df.to_csv(filepath, mode='a', header=not os.path.exists(filepath))

        filepath = f"{path}y_train_{k}.csv"
        y_train_df.to_csv(filepath,mode='a', header=not os.path.exists(filepath))

        filepath = f"{path}X_val_{k}.csv"
        X_val_df.to_csv(filepath,mode='a', header=not os.path.exists(filepath))

        filepath = f"{path}y_val_{k}.csv"
        y_val_df.to_csv(filepath,mode='a', header=not os.path.exists(filepath))



    # create test data
    test_data = df[df['csn'].isin(csns_test)]
    X_test_df = test_data
    y_test_df = test_data[y]

    # save test data
    filepath = f"{path}X_test.csv"
    X_test_df.to_csv(filepath,mode='a', header=not os.path.exists(filepath))

    filepath = f"{path}y_test.csv"
    y_test_df.to_csv(filepath,mode='a', header=not os.path.exists(filepath))
# Out:
# Number of patients in training set: 8128
# Number of encounters (csn): 8128
# Years: [2016 2017 2018]
# Start year: 2016
# End year: 2018
# Number of unique patient visits: 8128
# Number of unique patients: 7724
# Number of sepsis=1 patients: 2953 (36.33%)
# Number of sepsis=0 patients: 5175 (63.67%)
# Number of patients in test set: 5161
# Number of encounters (csn): 5161
# Years: [2019 2020]
# Start year: 2019
# End year: 2020
# Number of unique patient visits: 5161
# Number of unique patients: 4883
# Number of sepsis=1 patients: 1819 (35.25%)
# Number of sepsis=0 patients: 3342 (64.75%)
# 100%|██████████| 5/5 [13:22<00:00, 160.55s/it]

# %% [markdown]
# ## Load Training, Validation, and Test Data

# %%
# read files from the current run
path = config['DIR']['train_test_split'].format(RUN=RUN)

# set prefix for csv files
prefix = "X_train"

# get the count of the files
k = utils.get_max_index(path,prefix) + 1

# get columns to drop
drop_cols = config['model']['drop_cols']

# create data dictionary to collect each fold
data_dict = {}

for i in tqdm(range(k),leave=True):
    sub_dict={}
    sub_dict['X_train'] = pd.read_csv(f"{path}/X_train_{i}.csv",index_col = [0]).drop(columns=drop_cols,errors='ignore')
    sub_dict['y_train'] = pd.read_csv(f"{path}/y_train_{i}.csv",index_col = [0])
    sub_dict['X_val'] = pd.read_csv(f"{path}/X_val_{i}.csv",index_col = [0]).drop(columns=drop_cols,errors='ignore')
    sub_dict['y_val'] = pd.read_csv(f"{path}/y_val_{i}.csv",index_col = [0])
    data_dict[i] = sub_dict
    
data_dict['X_test'] = pd.read_csv(f"{path}/X_test.csv",index_col = [0])
data_dict['y_test'] = pd.read_csv(f"{path}/y_test.csv",index_col = [0])
# Out:
# 100%|██████████| 5/5 [01:01<00:00, 12.27s/it]

# %% [markdown]
# ## ID and save positive cases

# %%
# create cases filename
filename = config['DIR']['cases'].format(RUN=RUN)

# identify cases
cases = data_dict['X_test'].groupby('csn')['sepsis_lag_6'].sum()

# save
pd.DataFrame(cases[cases > 0]).reset_index().to_csv(filename)

# %% [markdown]
# ## Model Training

# %%
run_cell = True
if run_cell:
    # Suppress specific warning from xgboost
    warnings.filterwarnings("ignore", message="ntree_limit is deprecated, use `iteration_range` or model slicing instead.")
    # select loss function
    loss_functions = ['Accuracy','F1_Score','F2_Score'] #'Accuracy','F1_Score','F2_Score'

    for loss_function_name in loss_functions:
        print(f"Training Models using {loss_function_name}")

        model_path = config['DIR']['models'].format(RUN=RUN,OBJECTIVE=loss_function_name)
        if not os.path.exists(model_path):
            os.mkdir(model_path)
            print(f"Created {loss_function_name} Directory")

        for i in range(k):

            # set training data
            X = data_dict[i]['X_train'].replace({np.inf:np.nan, -np.inf:np.nan})
            
            X['y'] = data_dict[i]['y_train']

            # downsample the training data
            X = md.downsample(X,'y')

            # assign X & y train values
            y_train = X['y'].values
            X_train = X.drop(columns=['y'],errors='ignore').values

            print(f"Training Data Shape: {np.shape(X_train)}")
            print(f"Number of positive sepsis hours: {sum(y_train)}")
            print("\n")

            # set validation data
            X_val = data_dict[i]['X_val'].replace({np.inf:np.nan, -np.inf:np.nan}).drop(columns=['y'],errors='ignore')
           
            X_val = X_val.values
            
            y_val = data_dict[i]['y_val'].values

            print(f"Validation Data Shape: {np.shape(X_val)}")
            print(f"Number of positive sepsis hours: {sum(y_val)}")

            md.train_model(i, X_train, y_train, X_val, y_val, loss_function_name, save_model_dir=model_path)
# Out:
# Training Models using Accuracy
# Training Data Shape: (3470, 212)
# Number of positive sepsis hours: 1735.0
#
#
# Validation Data Shape: (495941, 212)
# Number of positive sepsis hours: [460.]
# Loss function being used: Accuracy
# *************************************************************
# 1th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:25<00:00,  7.28s/trial, best loss: 0.0011170683609542653]
# obtained best_param
# training dataset AUC: 0.9751113288873756
# training dataset acc: 0.9259365994236312
# training dataset f2-score: 0.907394448332167
# validation dataset AUC: 0.8191693284777382
# validation dataset acc: 0.9987579167683253
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3588, 212)
# Number of positive sepsis hours: 1794.0
#
#
# Validation Data Shape: (492687, 212)
# Number of positive sepsis hours: [411.]
# Loss function being used: Accuracy
# *************************************************************
# 2th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [01:56<00:00,  5.81s/trial, best loss: 0.0019484987426093836]
# obtained best_param
# training dataset AUC: 0.9744698978012923
# training dataset acc: 0.935340022296544
# training dataset f2-score: 0.9144826028016269
# validation dataset AUC: 0.8224874528381099
# validation dataset acc: 0.9990663443524996
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3476, 212)
# Number of positive sepsis hours: 1738.0
#
#
# Validation Data Shape: (492116, 212)
# Number of positive sepsis hours: [458.]
# Loss function being used: Accuracy
# *************************************************************
# 3th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:01<00:00,  6.09s/trial, best loss: 0.0016053125685814296]
# obtained best_param
# training dataset AUC: 0.972269655080175
# training dataset acc: 0.9211737629459148
# training dataset f2-score: 0.9016775396085741
# validation dataset AUC: 0.8371987341610929
# validation dataset acc: 0.9990611969535638
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3520, 212)
# Number of positive sepsis hours: 1760.0
#
#
# Validation Data Shape: (490977, 212)
# Number of positive sepsis hours: [440.]
# Loss function being used: Accuracy
# *************************************************************
# 4th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:23<00:00,  7.16s/trial, best loss: 0.0013544422651162735]
# obtained best_param
# training dataset AUC: 0.9808191825929753
# training dataset acc: 0.9346590909090909
# training dataset f2-score: 0.9122867680958966
# validation dataset AUC: 0.8416194395122081
# validation dataset acc: 0.9990325412392026
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3586, 212)
# Number of positive sepsis hours: 1793.0
#
#
# Validation Data Shape: (491019, 212)
# Number of positive sepsis hours: [427.]
# Loss function being used: Accuracy
# *************************************************************
# 5th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:51<00:00,  8.55s/trial, best loss: 0.0008920225082940103]
# obtained best_param
# training dataset AUC: 0.9744145059379149
# training dataset acc: 0.9322364751812604
# training dataset f2-score: 0.9122232263895166
# validation dataset AUC: 0.8311607411136946
# validation dataset acc: 0.9991303798834669
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Models using F1_Score
# Training Data Shape: (3470, 212)
# Number of positive sepsis hours: 1735.0
#
#
# Validation Data Shape: (495941, 212)
# Number of positive sepsis hours: [460.]
# Loss function being used: F1_Score
# *************************************************************
# 1th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [01:46<00:00,  5.31s/trial, best loss: 0.9871106337271751]
# obtained best_param
# training dataset AUC: 0.9826270461510352
# training dataset acc: 0.9322766570605188
# training dataset f2-score: 0.9115860780191545
# validation dataset AUC: 0.8271144429440237
# validation dataset acc: 0.9987135566529083
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3588, 212)
# Number of positive sepsis hours: 1794.0
#
#
# Validation Data Shape: (492687, 212)
# Number of positive sepsis hours: [411.]
# Loss function being used: F1_Score
# *************************************************************
# 2th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:01<00:00,  6.09s/trial, best loss: 0.9836567926455567]
# obtained best_param
# training dataset AUC: 0.9617887383810024
# training dataset acc: 0.9347826086956522
# training dataset f2-score: 0.9132007233273056
# validation dataset AUC: 0.7565526758583138
# validation dataset acc: 0.9991657989758204
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3476, 212)
# Number of positive sepsis hours: 1738.0
#
#
# Validation Data Shape: (492116, 212)
# Number of positive sepsis hours: [458.]
# Loss function being used: F1_Score
# *************************************************************
# 3th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:14<00:00,  6.74s/trial, best loss: 0.9842726081258192]
# obtained best_param
# training dataset AUC: 0.9754241148576264
# training dataset acc: 0.9243383199079401
# training dataset f2-score: 0.9035793400956046
# validation dataset AUC: 0.8390078475397061
# validation dataset acc: 0.9984434564208439
# ************************************************************
# validation dataset f2-score: 0.006989748369058714
# ************************************************************
# Training Data Shape: (3520, 212)
# Number of positive sepsis hours: 1760.0
#
#
# Validation Data Shape: (490977, 212)
# Number of positive sepsis hours: [440.]
# Loss function being used: F1_Score
# *************************************************************
# 4th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [01:53<00:00,  5.70s/trial, best loss: 0.9894319682959049]
# obtained best_param
# training dataset AUC: 0.9918816180268595
# training dataset acc: 0.9434659090909091
# training dataset f2-score: 0.9239443102059601
# validation dataset AUC: 0.8342934514994421
# validation dataset acc: 0.9988716375716175
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3586, 212)
# Number of positive sepsis hours: 1793.0
#
#
# Validation Data Shape: (491019, 212)
# Number of positive sepsis hours: [427.]
# Loss function being used: F1_Score
# *************************************************************
# 5th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:22<00:00,  7.13s/trial, best loss: 0.9874869655891554]
# obtained best_param
# training dataset AUC: 0.9845526181789563
# training dataset acc: 0.9341885108756275
# training dataset f2-score: 0.9136625607413268
# validation dataset AUC: 0.8383748948075848
# validation dataset acc: 0.9989939289518328
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Models using F2_Score
# Training Data Shape: (3470, 212)
# Number of positive sepsis hours: 1735.0
#
#
# Validation Data Shape: (495941, 212)
# Number of positive sepsis hours: [460.]
# Loss function being used: F2_Score
# *************************************************************
# 1th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:09<00:00,  6.46s/trial, best loss: 0.9835255354200988]
# obtained best_param
# training dataset AUC: 0.9853781694059414
# training dataset acc: 0.9337175792507204
# training dataset f2-score: 0.9124897768430892
# validation dataset AUC: 0.8175667947781615
# validation dataset acc: 0.9987075075462606
# ************************************************************
# validation dataset f2-score: 0.0024715768660405336
# ************************************************************
# Training Data Shape: (3588, 212)
# Number of positive sepsis hours: 1794.0
#
#
# Validation Data Shape: (492687, 212)
# Number of positive sepsis hours: [411.]
# Loss function being used: F2_Score
# *************************************************************
# 2th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [02:23<00:00,  7.16s/trial, best loss: 0.9690721649484536]
# obtained best_param
# training dataset AUC: 0.9830369471382996
# training dataset acc: 0.9375696767001115
# training dataset f2-score: 0.9160262206148282
# validation dataset AUC: 0.818108925266322
# validation dataset acc: 0.9988978803987115
# ************************************************************
# validation dataset f2-score: 0.00281214848143982
# ************************************************************
# Training Data Shape: (3476, 212)
# Number of positive sepsis hours: 1738.0
#
#
# Validation Data Shape: (492116, 212)
# Number of positive sepsis hours: [458.]
# Loss function being used: F2_Score
# *************************************************************
# 3th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [01:43<00:00,  5.18s/trial, best loss: 0.9694821815317975]
# obtained best_param
# training dataset AUC: 0.9919167899295647
# training dataset acc: 0.9519562715765247
# training dataset f2-score: 0.9395661756176776
# validation dataset AUC: 0.8494821599194143
# validation dataset acc: 0.9955538937973973
# ************************************************************
# validation dataset f2-score: 0.018115942028985508
# ************************************************************
# Training Data Shape: (3520, 212)
# Number of positive sepsis hours: 1760.0
#
#
# Validation Data Shape: (490977, 212)
# Number of positive sepsis hours: [440.]
# Loss function being used: F2_Score
# *************************************************************
# 4th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [01:53<00:00,  5.70s/trial, best loss: 0.9851791969819456]
# obtained best_param
# training dataset AUC: 0.9827192019628099
# training dataset acc: 0.9380681818181819
# training dataset f2-score: 0.9168394379175304
# validation dataset AUC: 0.7954341248839165
# validation dataset acc: 0.998382816303004
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************
# Training Data Shape: (3586, 212)
# Number of positive sepsis hours: 1793.0
#
#
# Validation Data Shape: (491019, 212)
# Number of positive sepsis hours: [427.]
# Loss function being used: F2_Score
# *************************************************************
# 5th training ..............
# Hyperparameters optimization
# 100%|██████████| 20/20 [03:09<00:00,  9.50s/trial, best loss: 0.9859211584875301]
# obtained best_param
# training dataset AUC: 0.9778974066900188
# training dataset acc: 0.9364194088120469
# training dataset f2-score: 0.9155645981688708
# validation dataset AUC: 0.8003148411470413
# validation dataset acc: 0.9990183679246628
# ************************************************************
# validation dataset f2-score: 0.0
# ************************************************************

# %% [markdown]
# ## Run Model: Test Data

# %%
run_cell = True
right_censor_predictions = True
if run_cell:
    # identify columns to drop
    drop_cols = config['model']['drop_cols'] + ['y']

    # set validation data
    X_test = data_dict['X_test'].replace({np.inf:np.nan, -np.inf:np.nan})
    X_test['y'] = data_dict['y_test'].astype(int)

    # get patient csns in test set
    test_set = X_test['csn'].unique().tolist()

    # array of loss function types 
    loss_functions = ['Accuracy','F1_Score','F2_Score']  #'Accuracy','F1_Score',,'ROC_AUC_Score'

    # set prediction threshold
    prediction_thresh = 0.50
    
        
    # for each loss function-based model
    for loss_function_name in tqdm(loss_functions, leave=True): 
        
        # set path to model directory
        model_dir = config['DIR']['models'].format(RUN=RUN,OBJECTIVE=loss_function_name)

        # get the number of k_folds
        k_folds = utils.get_max_index(model_dir,'model')
        
        # set save path name for test predictions
        TYPE = 'hourly'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        if not os.path.exists(prediction_dir):
            os.mkdir(prediction_dir)
        outpath = os.path.join(prediction_dir,f'prediction_results_test_{TYPE}.csv')

        # make predictions on test set
        predictions = md.predict(test_set, X_test, model_dir, k_folds, outpath, prediction_thresh, drop_cols)
        
        # right censor predictions
        if right_censor_predictions:
            predictions = cohort.right_censor(predictions, 'y_true')
            # save updated predictions
            predictions.to_csv(outpath)
        # set save path for summarized prediction results
        TYPE = 'summary'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        outpath = os.path.join(prediction_dir,f'prediction_results_test_{TYPE}.csv')
        if not os.path.exists(prediction_dir):
            os.mkdir(prediction_dir)
            
        # summarize test prediction results
        test_results = md.summarize_predictions(predictions,'y_true','y_prob',prediction_thresh)
        
        # save test data 
        test_results.to_csv(outpath, index=False)
# Out:
# 100%|██████████| 5161/5161 [07:09<00:00, 12.02it/s]
# 100%|██████████| 5161/5161 [06:29<00:00, 13.25it/s]
# 100%|██████████| 5161/5161 [05:51<00:00, 14.70it/s]
# 100%|██████████| 3/3 [23:39<00:00, 473.11s/it]

# %% [markdown]
# ## Run Model: Training Data

# %%
run_cell= False
right_censor_predictions = True
if run_cell:
    X = cohort.load_reference_data('grady', config, verbose=True)
    X = cohort.update_cohort(X, verbose=True)
    df = cohort.load_hourly_data(config)
    
    # identify columns to drop
    drop_cols = config['model']['drop_cols'] + ['y']

    # identify y column name
    y_column = 'sepsis_lag_6'

    # create data set
    train_csns = X[X['year']<=2018]['csn'].unique().tolist()
    X = df[df['csn'].isin(train_csns)].copy()
    X['y'] = X[y_column]
    
    print('Data Loaded')

    # array of loss function types 
    loss_functions = ['Accuracy','F1_Score','F2_Score'] #'Accuracy','F1_Score','F2_Score','ROC_AUC_Score'

    # set prediction threshold
    prediction_thresh = 0.50

    # for each loss function-based model
    for loss_function_name in tqdm(loss_functions, leave=True): 
        # set path to model directory
        model_dir = config['DIR']['models'].format(RUN=RUN,OBJECTIVE=loss_function_name)

        # get the number of k_folds
        k_folds = utils.get_max_index(model_dir,'model')

        # set save path name for test predictions
        TYPE = 'hourly'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        outpath = os.path.join(prediction_dir,f'prediction_results_training_{TYPE}.csv')

        # make predictions on training set
        predictions = md.predict(train_csns, X, model_dir, k_folds, outpath, prediction_thresh, drop_cols)
        
        # right censor predictions
        if right_censor_predictions:
            predictions = cohort.right_censor(predictions, 'y_true')
            # save updated predictions
            predictions.to_csv(outpath)
            
        # set save path for summarized prediction results
        TYPE = 'summary'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        outpath = os.path.join(prediction_dir,f'prediction_results_training_{TYPE}.csv')

        # summarize test prediction results
        results = md.summarize_predictions(predictions,'y_true','y_prob',prediction_thresh)

        # save test data 
        results.to_csv(outpath, index=False)

# %% [markdown]
# ## Run Model: All Data

# %%
run_cell= False

if run_cell:
    X = cohort.load_reference_data('grady', config, verbose=True)
    X = cohort.update_cohort(X, verbose=True)
    
    # identify columns to drop
    drop_cols = config['meta']['drop_cols']

    # identify y column name
    y_column = 'sepsis_lag_6'

    # create data set
    X = df.copy()
    X['y'] = X[y_column]

    print('Data Loaded')

    # array of loss function types 
    loss_functions = ['Accuracy','F1_Score','F2_Score'] #'Accuracy','F1_Score','F2_Score','ROC_AUC_Score'

    # set prediction threshold
    prediction_thresh = 0.50

    # for each loss function-based model
    for loss_function_name in tqdm(loss_functions, leave=True): 
        # set path to model directory
        model_dir = config['DIR']['models'].format(RUN=RUN,OBJECTIVE=loss_function_name)

        # get the number of k_folds
        k_folds = utils.get_max_index(model_dir,'model')

        # set save path name for test predictions
        TYPE = 'hourly'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        outpath = os.path.join(prediction_dir,f'prediction_results_training_{TYPE}.csv')

        # make predictions on training set
        predictions = md.predict(all_csns, X, model_dir, k_folds, outpath, prediction_thresh, drop_cols)

        # remove data past 168 hour period
        predictions['hour'] = predictions.index
        predictions['hour'] = predictions['hour'].apply(lambda x: int(x.split('_')[1]))

        # set save path for summarized prediction results
        TYPE = 'summary'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        outpath = os.path.join(prediction_dir,f'prediction_results_training_{TYPE}.csv')

        # summarize test prediction results
        results = md.summarize_predictions(predictions,'y_true','y_prob',prediction_thresh)

        # save test data 
        results.to_csv(outpath, index=False)

# %% [markdown]
# ## Test for Individual Models

# %%
run_cell = True
if run_cell:
    # identify columns to drop
    drop_cols = config['model']['drop_cols']+['y']

    # set validation data
    X_test = data_dict['X_test'].replace({np.inf:np.nan, -np.inf:np.nan})
    X_test['y'] = data_dict['y_test'].astype(int)

    # get patient csns in test set
    test_set = X_test['csn'].unique().tolist()

    # array of loss function types 
    loss_functions = ['Accuracy','F1_Score','F2_Score']  #,'F1_Score','Accuracy',,'ROC_AUC_Score'

    # set prediction threshold
    prediction_thresh = 0.50

    
    # for each loss function-based model
    for loss_function_name in tqdm(loss_functions, leave=True): 
        # set path to model directory
        model_dir = config['DIR']['models'].format(RUN=RUN,OBJECTIVE=loss_function_name)

        # get the number of k_folds
        k_folds = utils.get_max_index(model_dir,'model')
        
        # set save path name for test predictions
        TYPE = 'hourly'
        prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = loss_function_name, TYPE=TYPE)
        if not os.path.exists(prediction_dir):
            os.mkdir(prediction_dir)
        outpath = os.path.join(prediction_dir,f'prediction_results_test_i_models.csv')

        # make predictions on test set
        predictions = md.predict_i(test_set, X_test, model_dir, k_folds, outpath, prediction_thresh, drop_cols)
        # right censor predictions
        if right_censor_predictions:
            predictions = cohort.right_censor(predictions, 'y_true')
            # save updated predictions
            # predictions.to_csv(outpath)
        # add ensemeble predictions
        prob_cols = [x for x in predictions.columns if "prob_" in x]
        predictions['ensemble_prob'] = predictions[prob_cols].mean(axis=1)
        predictions['ensemble_label'] = np.where(predictions['ensemble_prob']<prediction_thresh,0,1)

        # save predictions
        predictions.to_csv(outpath)
# Out:
# 100%|██████████| 5161/5161 [03:15<00:00, 26.40it/s]
# 100%|██████████| 5161/5161 [03:05<00:00, 27.77it/s]
# 100%|██████████| 5161/5161 [03:14<00:00, 26.52it/s]
# 100%|██████████| 3/3 [10:25<00:00, 208.64s/it]

# %% [markdown]
# ## Load Individual Model Performance Metrics

# %%
OBJECTIVE = "F2_Score"
TYPE = 'hourly'
prediction_dir = config['DIR']['predictions'].format(RUN=RUN, OBJECTIVE = OBJECTIVE, TYPE=TYPE)
path = os.path.join(prediction_dir,f'prediction_results_test_i_models.csv')
predictions = pd.read_csv(path, index_col=0)

# %% [markdown]
# ## Summarize Individual and Ensemble Model Performance

# %%
k_folds = 5
prediction_thresh = 0.5
model_predictions = []
for i in range(k_folds):
    i = i+1
    model_i_metrics = md.summarize_predictions_i(predictions,'y_true',f'prob_{i}',prediction_thresh)
    model_i_metrics['model'] = i
    model_i_metrics['thresh'] = prediction_thresh
    model_predictions.append(model_i_metrics)

model_pred_df = pd.concat(model_predictions,axis=0)

ens_pred = md.summarize_predictions_i(predictions,'y_true',f'ensemble_prob',prediction_thresh)
ens_pred['model'] = 'ensemble'
ens_pred['thresh'] = prediction_thresh
model_pred_df = pd.concat([model_pred_df,ens_pred], axis=0)
display(model_pred_df[['model','accuracy','roc_auc','f2_score']])
model_pred_df[['model','accuracy','roc_auc','f2_score']].mean(axis=0)
# Out:
#       model  accuracy   roc_auc  f2_score
# 0         1  0.990211  0.882202  0.537604
# 0         2  0.991182  0.882400  0.557652
# 0         3  0.985972  0.882969  0.466565
# 0         4  0.985957  0.880067  0.463505
# 0         5  0.988988  0.882746  0.515205
# 0  ensemble  0.991359  0.882778  0.561840
# accuracy    0.988945
# roc_auc     0.882193
# f2_score    0.517062
# dtype: float64

# %% [markdown]
# ## Visualize MCC Performance Across Prediction Thresholds

# %%
# init results list
ens_results = []
# iterate through all possible prediction thresholds
for i in range(1,101):
    i/=100
    ens_pred_i = md.summarize_predictions_i(predictions,'y_true',f'ensemble_prob',i)
    ens_pred_i["thresh"] = i
    ens_results.append(ens_pred_i)
ens_df = pd.concat(ens_results, axis=0)

ens_df.plot(x="thresh",y=["accuracy","f1_score","f2_score"])
# isolate a range of thresholds
rt = ens_df[(ens_df['thresh']>=0.2)&(ens_df['thresh']<0.8)]

# Create the line plot
plt.figure(figsize=(8, 6))
y_axis = "mcc"
plt.plot(rt['thresh'], rt[y_axis], marker='o', color='black', label='MCC')  # 'o' creates the circular markers

# Labeling the axes
plt.xlabel('Prediction threshold')
plt.ylabel(f'MCC')
plt.legend(loc='upper right')

# Show the grid
plt.grid(True)

# save the plot
save_path = f"MBD_Runs/{RUN}/images/MCC.png"
# plt.savefig(save_path, dpi=600)
# Display the plot
plt.show()

# %%
rt[rt['mcc']==rt['mcc'].max()]
# Out:
#    true_negative  false_positive  false_negative  true_positive       mcc  \
# 0       430866.0         32621.0           937.0          784.0  0.090575
#
#         tpr       fpr  f1_score  f2_score  precision    recall  accuracy  \
# 0  0.455549  0.070382  0.044639  0.097297    0.02347  0.455549  0.927865
#
#     roc_auc  thresh
# 0  0.692584    0.77

# %% [markdown]
# ## Analysis for difference in numbers between F1 & F2 score in positive cases

# %%
t = data_dict['X_test']
ty = data_dict['y_test']
q_csns = [1028157978,1028525986,1027984245,1039225718]
t[t['csn'].isin(q_csns)]['sepsis_lag_6'].sum()
ty.loc[t[t['csn'].isin(q_csns)].index]

idx = [8710_42,9066_47,11204_109,12422_0,]
(t['sepsis_lag_6']!=ty['sepsis_lag_6']).sum()
# Out:
# 0

# %%
data_dict[0]['X_train']
data_dict['X_test']
# Out:
#           alanine_aminotransferase_(alt)  albumin  alkaline_phosphatase  \
# 8128_0                              26.0      3.7                  99.0
# 8128_1                              26.0      3.7                  99.0
# 8128_2                              26.0      3.7                  99.0
# 8128_3                              26.0      3.7                  99.0
# 8128_4                              26.0      3.7                  99.0
# ...                                  ...      ...                   ...
# 13288_46                            27.0      4.2                  46.0
# 13288_47                            27.0      4.2                  46.0
# 13288_48                            27.0      4.2                  46.0
# 13288_49                            27.0      4.2                  46.0
# 13288_50                            27.0      4.2                  46.0
#
#           anion_gap  aspartate_aminotransferase_(ast)  base_excess  best_map  \
# 8128_0          9.0                              33.0         -3.4      69.0
# 8128_1          9.0                              33.0         -3.4      83.0
# 8128_2          9.0                              33.0         -3.4      77.0
# 8128_3          9.0                              33.0         -3.4      81.0
# 8128_4          9.0                              33.0         -3.4      85.0
# ...             ...                               ...          ...       ...
# 13288_46       15.0                              87.0         -6.7     102.0
# 13288_47       15.0                              87.0         -6.7     107.0
# 13288_48       15.0                              87.0         -6.7      93.0
# 13288_49       15.0                              87.0         -6.7      99.0
# 13288_50       15.0                              87.0         -6.7      99.0
#
#           bicarb_(hco3)  bilirubin_total  blood_urea_nitrogen_(bun)  calcium  \
# 8128_0             24.0              1.1                       11.0      8.8
# 8128_1             24.0              1.1                       11.0      8.8
# 8128_2             24.0              1.1                       11.0      8.8
# 8128_3             24.0              1.1                       11.0      8.8
# 8128_4             24.0              1.1                       11.0      8.8
# ...                 ...              ...                        ...      ...
# 13288_46           24.0              1.5                        6.0      8.6
# 13288_47           24.0              1.5                        6.0      8.6
# 13288_48           24.0              1.5                        6.0      8.6
# 13288_49           24.0              1.5                        6.0      8.6
# 13288_50           24.0              1.5                        6.0      8.6
#
#           chloride  creatinine  daily_weight_kg  ed  fio2  gcs_total_score  \
# 8128_0       101.0         0.9             74.8   0   0.4              8.0
# 8128_1       101.0         0.9             74.8   0   0.4              8.0
# 8128_2       101.0         0.9             74.8   0   0.4              9.0
# 8128_3       101.0         0.9             74.8   0   0.4              9.0
# 8128_4       101.0         0.9             74.8   0   0.4              9.0
# ...            ...         ...              ...  ..   ...              ...
# 13288_46     100.0         0.8             66.2   0   0.3             15.0
# 13288_47     100.0         0.8             66.2   0   0.3             15.0
# 13288_48     100.0         0.8             66.2   0   0.3             15.0
# 13288_49     100.0         0.8             66.2   0   0.3             15.0
# 13288_50     100.0         0.8             66.2   0   0.3             15.0
#
#           glucose  hematocrit  hemoglobin  icu  imc  magnesium  \
# 8128_0      334.0        39.9        13.4    1    0        1.1
# 8128_1      334.0        39.9        13.4    1    0        1.1
# 8128_2      334.0        39.9        13.4    1    0        1.1
# 8128_3      334.0        39.9        13.4    1    0        1.1
# 8128_4      334.0        39.9        13.4    1    0        1.1
# ...           ...         ...         ...  ...  ...        ...
# 13288_46    125.0        34.7        11.9    1    0        2.0
# 13288_47    125.0        34.7        11.9    1    0        2.0
# 13288_48    125.0        34.7        11.9    1    0        2.0
# 13288_49    125.0        34.7        11.9    1    0        2.0
# 13288_50    125.0        34.7        11.9    1    0        2.0
#
#           partial_pressure_of_carbon_dioxide_(paco2)  \
# 8128_0                                          25.0
# 8128_1                                          25.0
# 8128_2                                          25.0
# 8128_3                                          25.0
# 8128_4                                          25.0
# ...                                              ...
# 13288_46                                        30.0
# 13288_47                                        30.0
# 13288_48                                        30.0
# 13288_49                                        30.0
# 13288_50                                        30.0
#
#           partial_pressure_of_oxygen_(pao2)       pf_pa   pf_sp    ph  \
# 8128_0                                212.0  530.000000  247.50  7.49
# 8128_1                                212.0  530.000000  247.50  7.49
# 8128_2                                212.0  530.000000  247.50  7.49
# 8128_3                                212.0  530.000000  248.75  7.49
# 8128_4                                212.0  530.000000  245.00  7.49
# ...                                     ...         ...     ...   ...
# 13288_46                              289.0  963.333333  330.00  7.38
# 13288_47                              289.0  963.333333  330.00  7.38
# 13288_48                              289.0  963.333333  330.00  7.38
# 13288_49                              289.0  963.333333  330.00  7.38
# 13288_50                              289.0  963.333333  330.00  7.38
#
#           phosphorus  platelets  potassium  procedure  protein  pulse  sodium  \
# 8128_0           2.0      152.0        3.5          0      6.2   76.0   134.0
# 8128_1           2.0      152.0        3.5          0      6.2   74.0   134.0
# 8128_2           2.0      152.0        3.5          0      6.2   68.0   134.0
# 8128_3           2.0      152.0        3.5          0      6.2   62.0   134.0
# 8128_4           2.0      152.0        3.5          0      6.2   65.0   134.0
# ...              ...        ...        ...        ...      ...    ...     ...
# 13288_46         3.1      155.0        3.8          0      6.5   77.0   139.0
# 13288_50                  0.0           0.0                  50.0
#
#           chloride_interval_f2  chloride_diff  creatinine_interval_f1  \
# 8128_0                     0.0            NaN                     1.0
# 8128_1                     0.0            0.0                     2.0
# 8128_2                     0.0            0.0                     3.0
# 8128_3                     0.0            0.0                     4.0
# 8128_4                     0.0            0.0                     5.0
# ...                        ...            ...                     ...
# 13288_46                   0.0            0.0                    44.0
# 13288_47                   0.0            0.0                    48.0
# 13288_48                   0.0            0.0                    49.0
# 13288_49                   0.0            0.0                    50.0
# 13288_50                   0.0            0.0                    50.0
#
#           creatinine_interval_f2  creatinine_diff  \
# 8128_0                       0.0              NaN
# 8128_1                       0.0              0.0
# 8128_2                       0.0              0.0
# 8128_3                       0.0              0.0
# 8128_4                       0.0              0.0
# ...                          ...              ...
# 13288_46                     0.0              0.0
# 13288_47                     0.0              0.0
# 13288_48                     0.0              0.0
# 13288_49                     0.0              0.0
# 13288_50                     0.0              0.0
#
#           daily_weight_kg_interval_f1  daily_weight_kg_interval_f2  \
# 8128_0                            1.0                          0.0
# 8128_1                            2.0                          0.0
# 8128_2                            3.0                          0.0
# 8128_3                            4.0                          0.0
# 8128_4                            5.0                          0.0
# ...                               ...                          ...
# 13288_46                         44.0                          0.0
# 13288_47                         48.0                          0.0
# 13288_48                         49.0                          0.0
# 13288_49                         50.0                          0.0
# 13288_50                         50.0                          0.0
#
#           daily_weight_kg_diff  fio2_interval_f1  fio2_interval_f2  fio2_diff  \
# 8128_0                     NaN               1.0               0.0        NaN
# 8128_1                     0.0               2.0               0.0        0.0
# 8128_2                     0.0               3.0               0.0        0.0
# 8128_3                     0.0               4.0               0.0        0.0
# 8128_4                     0.0               5.0               0.0        0.0
# ...                        ...               ...               ...        ...
# 13288_46                   0.0              44.0               0.0        0.0
# 13288_47                   0.0              48.0               0.0        0.0
# 13288_48                   0.0              49.0               0.0        0.0
# 13288_49                   0.0              50.0               0.0        0.0
# 13288_50                   0.0              50.0               0.0        0.0
#
#           gcs_total_score_interval_f1  gcs_total_score_interval_f2  \
# 8128_0                            1.0                          0.0
# 8128_1                            2.0                          0.0
# 8128_2                            3.0                          0.0
# 8128_3                            4.0                          0.0
# 8128_4                            5.0                          0.0
# ...                               ...                          ...
# 13288_46                         44.0                          0.0
# 13288_47                         48.0                          0.0
# 13288_48                         49.0                          0.0
# 13288_49                         50.0                          0.0
# 13288_50                         50.0                          0.0
#
#           gcs_total_score_diff  glucose_interval_f1  glucose_interval_f2  \
# 8128_0                     NaN                  1.0                  0.0
# 8128_1                     0.0                  2.0                  0.0
# 8128_2                     1.0                  3.0                  0.0
# 8128_3                     0.0                  4.0                  0.0
# 8128_4                     0.0                  5.0                  0.0
# ...                        ...                  ...                  ...
# 13288_46                   0.0                 44.0                  0.0
# 13288_47                   0.0                 48.0                  0.0
# 13288_48                   0.0                 49.0                  0.0
# 13288_49                   0.0                 50.0                  0.0
# 13288_50                   0.0                 50.0                  0.0
#
#           glucose_diff  hematocrit_interval_f1  hematocrit_interval_f2  \
# 8128_4                                              5.0
# ...                                                 ...
# 13288_46                                           44.0
# 13288_47                                           48.0
# 13288_48                                           49.0
# 13288_49                                           50.0
# 13288_50                                           50.0
#
#           partial_pressure_of_oxygen_(pao2)_interval_f2  \
# 8128_0                                              0.0
# 8128_1                                              0.0
# 8128_2                                              0.0
# 8128_3                                              0.0
# 8128_4                                              0.0
# ...                                                 ...
# 13288_46                                            0.0
# 13288_47                                            0.0
# 13288_48                                            0.0
# 13288_49                                            0.0
# 13288_50                                            0.0
#
#           partial_pressure_of_oxygen_(pao2)_diff  pf_pa_interval_f1  \
# 8128_0                                       NaN                1.0
# 8128_1                                       0.0                2.0
# 8128_2                                       0.0                3.0
# 8128_3                                       0.0                4.0
# 8128_4                                       0.0                5.0
# ...                                          ...                ...
# 13288_46                                     0.0               44.0
# 13288_47                                     0.0               48.0
# 13288_48                                     0.0               49.0
# 13288_49                                     0.0               50.0
# 13288_50                                     0.0               50.0
#
#           pf_pa_interval_f2  pf_pa_diff  pf_sp_interval_f1  pf_sp_interval_f2  \
# 8128_0                  0.0         NaN                1.0                0.0
# 8128_1                  0.0         0.0                2.0                0.0
# 8128_2                  0.0         0.0                3.0                0.0
# 8128_3                  0.0         0.0                4.0                0.0
# 8128_4                  0.0         0.0                5.0                0.0
# ...                     ...         ...                ...                ...
# 13288_46                0.0         0.0               44.0                0.0
# 13288_47                0.0         0.0               48.0                0.0
# 13288_48                0.0         0.0               49.0                0.0
# 13288_49                0.0         0.0               50.0                0.0
# 13288_50                0.0         0.0               50.0                0.0
#
#           pf_sp_diff  ph_interval_f1  ph_interval_f2  ph_diff  \
# 8128_0           NaN             1.0             0.0      NaN
# 8128_1          0.00             2.0             0.0      0.0
# 8128_2          0.00             3.0             0.0      0.0
# 8128_3          1.25             4.0             0.0      0.0
# 8128_4         -3.75             5.0             0.0      0.0
# ...              ...             ...             ...      ...
# 13288_46        0.00            44.0             0.0      0.0
# 13288_47        0.00            48.0             0.0      0.0
# 13288_48        0.00            49.0             0.0      0.0
# 13288_49        0.00            50.0             0.0      0.0
# 13288_50        0.00            50.0             0.0      0.0
#
#           phosphorus_interval_f1  phosphorus_interval_f2  phosphorus_diff  \
# 8128_0                       1.0                     0.0              NaN
# 8128_1                       2.0                     0.0              0.0
# 8128_2                       3.0                     0.0              0.0
# 8128_3                       4.0                     0.0              0.0
# 8128_4                       5.0                     0.0              0.0
# ...                          ...                     ...              ...
# 13288_46                    44.0                     0.0              0.0
# 13288_47                    48.0                     0.0              0.0
# 13288_48                    49.0                     0.0              0.0
# 13288_49                    50.0                     0.0              0.0
# 13288_50                    50.0                     0.0              0.0
#
#           platelets_interval_f1  platelets_interval_f2  platelets_diff  \
# 8128_0                      1.0                    0.0             NaN
# 8128_1                      2.0                    0.0             0.0
# 8128_2                      3.0                    0.0             0.0
# 8128_3                      4.0                    0.0             0.0
# 8128_4                      5.0                    0.0             0.0
# ...                         ...                    ...             ...
# 13288_46                   44.0                    0.0             0.0
#           sofa_score_total_interval_f1  sofa_score_total_interval_f2  \
# 8128_0                               1                           0.0
# 8128_1                               2                           0.0
# 8128_2                               3                           0.0
# 8128_3                               4                           0.0
# 8128_4                               5                           0.0
# ...                                ...                           ...
# 13288_46                            44                           0.0
# 13288_47                            48                           0.0
# 13288_48                            49                           0.0
# 13288_49                            50                           0.0
# 13288_50                            50                           0.0
#
#           sofa_score_total_diff  sirs_score_total_interval_f1  \
# 8128_0                      NaN                             1
# 8128_1                     -1.0                             2
# 8128_2                      0.0                             3
# 8128_3                      0.0                             4
# 8128_4                      0.0                             5
# ...                         ...                           ...
# 13288_46                    0.0                            44
# 13288_47                    0.0                            48
# 13288_48                    0.0                            49
# 13288_49                    0.0                            50
# 13288_50                    0.0                            50
#
#           sirs_score_total_interval_f2  sirs_score_total_diff  \
# 8128_0                             0.0                    NaN
# 8128_1                             0.0                    0.0
# 8128_2                             0.0                    0.0
# 8128_3                             0.0                    0.0
# 8128_4                             0.0                    0.0
# ...                                ...                    ...
# 13288_46                           0.0                   -1.0
# 13288_47                           0.0                    1.0
# 13288_48                           0.0                    0.0
# 13288_49                           0.0                    0.0
# 13288_50                           0.0                    0.0
#
#           sbp_line_interval_f1  sbp_line_interval_f2  sbp_line_diff  \
# 8128_0                     0.0                  -1.0            NaN
# 8128_1                     0.0                  -1.0            NaN
# 8128_2                     0.0                  -1.0            NaN
# 8128_3                     0.0                  -1.0            NaN
# 8128_4                     0.0                  -1.0            NaN
# ...                        ...                   ...            ...
# 13288_46                   0.0                  -1.0            NaN
# 13288_47                   0.0                  -1.0            NaN
# 13288_48                   0.0                  -1.0            NaN
# 13288_49                   0.0                  -1.0            NaN
# 13288_50                   0.0                  -1.0            NaN
#
#           dbp_line_interval_f1  dbp_line_interval_f2  dbp_line_diff  \
# 8128_0                     0.0                  -1.0            NaN
# 8128_1                     0.0                  -1.0            NaN
# 8128_2                     0.0                  -1.0            NaN
# 8128_3                     0.0                  -1.0            NaN
# 8128_4                     0.0                  -1.0            NaN
# ...                        ...                   ...            ...
# 13288_46                   0.0                  -1.0            NaN
# 13288_47                   0.0                  -1.0            NaN
# 13288_48                   0.0                  -1.0            NaN
# 13288_49                   0.0                  -1.0            NaN
# 13288_50                   0.0                  -1.0            NaN
#
#           map_line_interval_f1  map_line_interval_f2  map_line_diff  \
# 8128_0                     0.0                  -1.0            NaN
# 8128_1                     0.0                  -1.0            NaN
# 8128_2                     0.0                  -1.0            NaN
# 8128_3                     0.0                  -1.0            NaN
# 8128_4                     0.0                  -1.0            NaN
# ...                        ...                   ...            ...
# 13288_46                   0.0                  -1.0            NaN
# 13288_47                   0.0                  -1.0            NaN
# 13288_48                   0.0                  -1.0            NaN
# 13288_49                   0.0                  -1.0            NaN
# 13288_50                   0.0                  -1.0            NaN
#
#           best_map_interval_f1  best_map_interval_f2  best_map_diff  \
# 8128_0                     1.0                   0.0            NaN
# 8128_1                     2.0                   0.0           14.0
# 8128_2                     3.0                   0.0           -6.0
# 8128_3                     4.0                   0.0            4.0
# 8128_4                     5.0                   0.0            4.0
# ...                        ...                   ...            ...
# 13288_46                  44.0                   0.0            4.0
# 13288_47                  48.0                   0.0            5.0
# 13288_48                  49.0                   0.0          -14.0
# 13288_49                  50.0                   0.0            6.0
# 13288_50                  50.0                   0.0            6.0
#
#           mean_pulse  mean_spo2  mean_unassisted_resp_rate  mean_temperature  \
# 8128_0     76.000000  99.000000                  14.000000        100.200000
# 8128_1     75.000000  99.000000                  14.000000        100.200000
# 8128_2     72.666667  99.000000                  14.000000        100.200000
# 8128_3     70.000000  99.125000                  14.000000        100.200000
# 8128_4     69.000000  98.900000                  14.000000        100.200000
# ...              ...        ...                        ...               ...
# 13288_46   86.000000  99.000000                  18.000000        101.066667
# 13288_47   85.000000  99.000000                  18.000000        101.083333
# 13288_48   82.500000  99.000000                  18.166667        101.100000
# 13288_49   88.333333  98.666667                  18.666667        101.100000
# 13288_50   94.166667  98.333333                  19.166667        101.100000
#
#           mean_sbp_line  mean_dbp_line  mean_map_line  mean_best_map  \
# 8128_0              NaN            NaN            NaN      69.000000
# 8128_1              NaN            NaN            NaN      76.000000
# 8128_2              NaN            NaN            NaN      76.333333
# 8128_3              NaN            NaN            NaN      77.500000
# 8128_4              NaN            NaN            NaN      79.000000
# ...                 ...            ...            ...            ...
# 13288_46            NaN            NaN            NaN     100.666667
# 13288_47            NaN            NaN            NaN     102.166667
# 13288_48            NaN            NaN            NaN     101.333333
# 13288_49            NaN            NaN            NaN     100.833333
# 13288_50            NaN            NaN            NaN     100.333333
#
#           median_pulse  median_spo2  median_unassisted_resp_rate  \
# 8128_0            76.0         99.0                         14.0
# 8128_1            75.0         99.0                         14.0
# 8128_2            74.0         99.0                         14.0
# 8128_3            71.0         99.0                         14.0
# 8128_4            68.0         99.0                         14.0
# ...                ...          ...                          ...
# 13288_46          77.0         99.0                         17.0
# 13288_47          77.0         99.0                         17.0
# 13288_48          77.0         99.0                         17.0
# 13288_49          83.0         99.0                         18.5
# 13288_50          93.5         99.0                         20.0
#
#           median_temperature  median_sbp_line  median_dbp_line  \
# 8128_0                 100.2              NaN              NaN
# 8128_1                 100.2              NaN              NaN
# 8128_2                 100.2              NaN              NaN
# 8128_3                 100.2              NaN              NaN
# 8128_4                 100.2              NaN              NaN
# ...                      ...              ...              ...
# 13288_46               101.1              NaN              NaN
# 13288_47               101.1              NaN              NaN
# 13288_48               101.1              NaN              NaN
# 13288_49               101.1              NaN              NaN
# 13288_50               101.1              NaN              NaN
#
#           median_map_line  median_best_map  min_pulse  min_spo2  \
# 8128_0                NaN             69.0       76.0      99.0
# 8128_1                NaN             76.0       74.0      99.0
# 8128_2                NaN             77.0       68.0      99.0
# 8128_3                NaN             79.0       62.0      99.0
# 8128_4                NaN             81.0       62.0      98.0
# ...                   ...              ...        ...       ...
# 13288_46              NaN            102.0       77.0      99.0
# 13288_47              NaN            102.0       77.0      99.0
# 13288_48              NaN            102.0       77.0      99.0
# 13288_49              NaN            102.0       77.0      97.0
# 13288_50              NaN            100.5       77.0      97.0
#
#           min_unassisted_resp_rate  min_temperature  min_sbp_line  \
# 8128_0                        14.0            100.2           NaN
# 8128_1                        14.0            100.2           NaN
# 8128_2                        14.0            100.2           NaN
# 8128_3                        14.0            100.2           NaN
# 8128_4                        14.0            100.2           NaN
# ...                            ...              ...           ...
# 13288_46                      17.0            101.0           NaN
# 13288_47                      17.0            101.0           NaN
# 13288_48                      17.0            101.1           NaN
# 13288_49                      17.0            101.1           NaN
# 13288_50                      17.0            101.1           NaN
#
#           min_dbp_line  min_map_line  min_best_map  max_pulse  max_spo2  \
# 8128_0             NaN           NaN          69.0       76.0      99.0
# 8128_1             NaN           NaN          69.0       76.0      99.0
# 8128_2             NaN           NaN          69.0       76.0      99.0
# 8128_3             NaN           NaN          69.0       76.0      99.5
# 8128_4             NaN           NaN          69.0       76.0      99.5
# ...                ...           ...           ...        ...       ...
# 13288_46           NaN           NaN          98.0      104.0      99.0
# 13288_47           NaN           NaN          98.0      104.0      99.0
# 13288_48           NaN           NaN          93.0       98.0      99.0
# 13288_49           NaN           NaN          93.0      112.0      99.0
# 13288_50           NaN           NaN          93.0      112.0      99.0
#
#           max_unassisted_resp_rate  max_temperature  max_sbp_line  \
# 8128_0                        14.0            100.2           NaN
# 8128_1                        14.0            100.2           NaN
# 8128_2                        14.0            100.2           NaN
# 8128_3                        14.0            100.2           NaN
# 8128_4                        14.0            100.2           NaN
# ...                            ...              ...           ...
# 13288_46                      20.0            101.1           NaN
# 13288_47                      20.0            101.1           NaN
# 13288_48                      21.0            101.1           NaN
# 13288_49                      21.0            101.1           NaN
# 13288_50                      21.0            101.1           NaN
#
#           max_dbp_line  max_map_line  max_best_map  std_pulse  std_spo2  \
# 8128_0             NaN           NaN          69.0        NaN       NaN
# 8128_1             NaN           NaN          83.0   1.414214  0.000000
# 8128_2             NaN           NaN          83.0   4.163332  0.000000
# 8128_3             NaN           NaN          83.0   6.324555  0.250000
# 8128_4             NaN           NaN          85.0   5.916080  0.547723
# ...                ...           ...           ...        ...       ...
# 13288_46           NaN           NaN         102.0  13.942740  0.000000
# 13288_47           NaN           NaN         107.0  12.537942  0.000000
# 13288_48           NaN           NaN         107.0   8.983318  0.000000
# 13288_49           NaN           NaN         107.0  14.417582  0.816497
# 13288_50           NaN           NaN         107.0  15.917496  1.032796
#
#           std_unassisted_resp_rate  std_temperature  std_sbp_line  \
# 8128_0                         NaN              NaN           NaN
# 8128_1                    0.000000     0.000000e+00           NaN
# 8128_2                    0.000000     0.000000e+00           NaN
# 8128_3                    0.000000     0.000000e+00           NaN
# 8128_4                    0.000000     0.000000e+00           NaN
# ...                            ...              ...           ...
# 13288_46                  1.549193     5.163978e-02           NaN
# 13288_47                  1.549193     4.082483e-02           NaN
# 13288_48                  1.834848     2.361802e-07           NaN
# 13288_49                  1.861899     2.361802e-07           NaN
# 13288_50                  1.722401     2.361802e-07           NaN
#
#           std_dbp_line  std_map_line  std_best_map  dstd_pulse     dstd_spo2  \
# 8128_0             NaN           NaN           NaN         NaN           NaN
# 8128_1             NaN           NaN      9.899495    2.828427  0.000000e+00
# 8128_2             NaN           NaN      7.023769    2.309401  2.886751e-01
# 8128_3             NaN           NaN      6.191392    4.272002  8.660254e-01
# 8128_4             NaN           NaN      6.324555    3.701351  7.582875e-01
# ...                ...           ...           ...         ...           ...
# 13288_46           NaN           NaN      2.065591   15.257785  4.986882e-08
# 13288_47           NaN           NaN      2.857738   15.578832  4.986882e-08
# 13288_48           NaN           NaN      4.546061   13.014095  8.164966e-01
# 13288_49           NaN           NaN      4.622409   13.014095  8.164966e-01
# 13288_50           NaN           NaN      4.633213   14.195070  8.944272e-01
#
#           dstd_unassisted_resp_rate  dstd_temperature  dstd_sbp_line  \
# 8128_0                          NaN               NaN            NaN
# 8128_1                     0.000000      0.000000e+00            NaN
# 8128_2                     0.000000      0.000000e+00            NaN
# 8128_3                     0.000000      0.000000e+00            NaN
# 8128_4                     0.000000      0.000000e+00            NaN
# ...                             ...               ...            ...
# 13288_46                   1.897367      4.082483e-02            NaN
# 13288_47                   1.940790      4.082483e-02            NaN
# 13288_48                   1.378405      1.953559e-09            NaN
# 13288_49                   1.378405      1.953559e-09            NaN
# 13288_50                   1.516575      2.184145e-09            NaN
#
#           dstd_dbp_line  dstd_map_line  dstd_best_map  pulse_score  \
# 8128_0              NaN            NaN            NaN          0.0
# 8128_1              NaN            NaN      14.142136          0.0
# 8128_2              NaN            NaN      10.000000          0.0
# 8128_3              NaN            NaN       8.164966          0.0
# 8128_4              NaN            NaN       7.924645          0.0
# ...                 ...            ...            ...          ...
# 13288_46            NaN            NaN       2.345208          0.0
# 13288_47            NaN            NaN       6.823977          1.0
# 13288_48            NaN            NaN       7.148426          0.0
# 13288_49            NaN            NaN       7.148426          2.0
# 13288_50            NaN            NaN       7.987490          2.0
#
#           temperature_score  unassisted_resp_rate_score  map_line_score  \
# 8128_0                  2.0                         0.0             NaN
# 8128_1                  2.0                         0.0             NaN
# 8128_2                  2.0                         0.0             NaN
# 8128_3                  2.0                         0.0             NaN
# 8128_4                  2.0                         0.0             NaN
# ...                     ...                         ...             ...
# 13288_46                2.0                         0.0             NaN
# 13288_47                2.0                         0.0             NaN
# 13288_48                2.0                         2.0             NaN
# 13288_49                2.0                         0.0             NaN
# 13288_50                2.0                         0.0             NaN
#
#           creatinine_score  qsofa  platelets_score  bilirubin_score
# 8128_0                 0.0    NaN              0.0              0.0
# 8128_1                 0.0    NaN              0.0              0.0
# 8128_2                 0.0    NaN              0.0              0.0
# 8128_3                 0.0    NaN              0.0              0.0
# 8128_4                 0.0    NaN              0.0              0.0
# ...                    ...    ...              ...              ...
# 13288_46               0.0    NaN              0.0              1.0
# 13288_47               0.0    NaN              0.0              1.0
# 13288_48               0.0    NaN              0.0              1.0
# 13288_49               0.0    NaN              0.0              1.0
# 13288_50               0.0    NaN              0.0              1.0
#
# [465208 rows x 215 columns]
